# %%
import json
import pandas as pd
from tqdm import tqdm
from vgg16 import Vgg16
import numpy as np
import PIL.Image
from utils import *
from matplotlib import pyplot as plt
import cv2
import os
import cPickle as pickle
from keras.preprocessing import sequence

import shutil
import string

import collections
import nltk
from nltk.stem.wordnet import WordNetLemmatizer
from nltk.corpus import stopwords

# %%
def save_array_with_folder_create(folder_path,arr_name,arr):
    if not os.path.exists(folder_path):
        print("Creating folder: "+folder_path)
        os.makedirs(folder_path)
        
    save_array(folder_path + arr_name, arr)
    
def load_vectors(loc):
    return (load_array(loc+'.dat'),
        pickle.load(open(loc+'_words.pkl','rb')),
        pickle.load(open(loc+'_idx.pkl','rb')))   




def create_emb(vecs,words,wordidx,index2word,vocab_size):
    n_fact = vecs.shape[1]
    emb = np.zeros((vocab_size, n_fact))

    found = 0
    not_found = 0
    
    exclude = set(string.punctuation)
    for i in range(1,len(emb)):
        word = index2word[i]
        word = ''.join(ch for ch in word if ch not in exclude).lower()
        if word and re.match(r"^[a-zA-Z0-9\-]*$", word) and word in wordidx:
            src_idx = wordidx[word]
            emb[i] = vecs[src_idx]
            found +=1
        else:
            # If we can't find the word in glove, randomly initialize
            emb[i] = normal(scale=0.6, size=(n_fact,))
            not_found+=1
#             print(word)

    # This is our "rare word" id - we want to randomly initialize
    emb[-1] = normal(scale=0.6, size=(n_fact,))
    emb/=3
    
    print("Found = %d"%found)
    print("Not found = %d"%not_found)
        
    return emb

# %% [markdown]
# ## Pairing

# %%
pairing_path = "../../vqa/raw_questions/train/pairing.json"
with open(pairing_path) as data_file:    
        data = json.load(data_file)

# %%
imgId_qId_question_list = []
for questionJson in tqdm(data["questions"]):
    imgId_qId_question_list.append((questionJson["image_id"],questionJson["question_id"],questionJson["question"]))
#     print("Image id = %s" % questionJson["image_id"])
#     print("Question  = %s" % questionJson["question"])
#     print("Question id = %s" % questionJson["question_id"])
#     print("------------------")
# Out:
# 100%|██████████| 443757/443757 [00:00<00:00, 786727.85it/s]

# %%
imgId_qId_question_list[:10]
# Out:
# [(458752, 458752000, u'What is this photo taken looking through?'),
#  (458752, 458752001, u'What position is this man playing?'),
#  (458752, 458752002, u'What color is the players shirt?'),
#  (458752, 458752003, u'Is this man a professional baseball player?'),
#  (262146, 262146000, u'What color is the snow?'),
#  (262146, 262146001, u'What is the person doing?'),
#  (262146, 262146002, u'What color is the persons headwear?'),
#  (524291, 524291000, u"What is in the person's hand?"),
#  (524291, 524291001, u'Is the dog waiting?'),
#  (524291, 524291002, u'Is the dog looking at a tennis ball or frisbee?')]

# %%
key2Question_df = pd.DataFrame(imgId_qId_question_list,columns=['image_id', 'question_id', 'question'])

# %%
key2Question_df
# Out:
#         image_id  question_id  \
# 0         458752    458752000
# 1         458752    458752001
# 2         458752    458752002
# 3         458752    458752003
# 4         262146    262146000
# 5         262146    262146001
# 6         262146    262146002
# 7         524291    524291000
# 8         524291    524291001
# 9         524291    524291002
# 10        393221    393221000
# 11        393221    393221001
# 12        393221    393221002
# 13        393223    393223000
# 14        393223    393223001
# 15        393223    393223002
# 16        393223    393223003
# 17        393224    393224000
# 18        393224    393224001
# 19        393224    393224002
# 20        393224    393224003
# 21        393224    393224004
# 22        393224    393224005
# 23        524297    524297000
# 24        524297    524297001
# 25        524297    524297002
# 26        524297    524297003
# 27        393227    393227000
# 28        393227    393227001
# 29        393227    393227002
# ...          ...          ...
# 443727    305832    305832000
# 443728    305832    305832001
# 443729    305832    305832002
# 443730    131058    131058000
# 443731    131058    131058001
# 443732    131058    131058002
# 443733    131059    131059000
# 443734    131059    131059001
# 443735    131059    131059002
# 443736    131059    131059003
# 443737    131059    131059004
# 443738    131060    131060000
# 443739    131060    131060001
# 443740    131060    131060002
# 443741    393207    393207000
# 443742    393207    393207001
# 443743    393207    393207002
# 443744    262136    262136000
# 443745    262136    262136001
# 443746    262136    262136002
# 443747    262136    262136003
# 443748    131067    131067000
# 443749    131067    131067001
# 443750    131067    131067002
# 443751    524286    524286000
# 443752    524286    524286001
# 443753    524286    524286002
# 443754    524286    524286003
# 443755    524286    524286004
# 443756    524286    524286005
#
#                                                  question
# 0               What is this photo taken looking through?
# 1                      What position is this man playing?
# 2                        What color is the players shirt?
# 3             Is this man a professional baseball player?
# 4                                 What color is the snow?
# 5                               What is the person doing?
# 6                     What color is the persons headwear?
# 7                           What is in the person's hand?
# 8                                     Is the dog waiting?
# 9         Is the dog looking at a tennis ball or frisbee?
# 10                                       Is the sky blue?
# 11                        Is there snow on the mountains?
# 12                              What is the white streak?
# 13                                    Is the window open?
# 14                          What color is the toothbrush?
# 15                               What is the child doing?
# 16                                       Is she brushing?
# 17                                    Is the man smiling?
# 18         What is the business man doing in the picture?
# 19                  Does his tie pair well with his suit?
# 20                               Does the man look happy?
# 21                                Is this photo in color?
# 22                        Is the man wearing a plain tie?
# 23      Judging from the dress, was this taken in a La...
# 24                 What colors are shown in this picture?
# 25                           Are the men on the sidewalk?
# 26                         Was this photo taken recently?
# 27                            Does the guy have a tattoo?
# 28                            What is this man riding on?
# 29       How many tattoos can be seen on this man's body?
# ...                                                   ...
# 443727                         Has the fruit been peeled?
# 443728        What kind of juice is made with this fruit?
# 443729                           What color is the fruit?
# 443730                       What are the people wearing?
# 443731                  What type of product can be seen?
# 443732                What color is the customer's shirt?
# 443733                            What color is the tree?
# 443734                   What animals are in the picture?
# 443735                        Is this animal in the wild?
# 443736                      What type of animal is shown?
# 443737                     What is the animal shown here?
# 443738              Is this a stuffed monkey in the tree?
# 443739                               What is in the tree?
# 443740                    Is the animal in the tree real?
# 443741                 Is this a black and white picture?
# 443742                              Is this photo blurry?
# 443743                                  Is this in focus?
# 443744                       Can he be sharpening blades?
# 443745                             How heavy is this man?
# 443746   Is this a normal thing to see in recent history?
# 443747                    What is man doing on his cycle?
# 443748                What links the two chains together?
# 443749                               What is this object?
# 443750                             Is this made of metal?
# 443751                      How many keyboards are there?
# 443752                        What color is the keyboard?
# 443753             Is there a computer mouse on the desk?
# 443754                        What color is the computer?
# 443755                       Why are there two keyboards?
# 443756                                  Is that a laptop?
#
# [443757 rows x 3 columns]

# %% [markdown]
# # Answers

# %%
answers_path = "../../vqa/raw_questions/train/answers.json"
with open(answers_path) as data_file:    
        answer_data = json.load(data_file)

# %%
for answerJson in answer_data["annotations"][:1]:
    for key, value in answerJson.items():
        print("Key:")
        print(key)
#     print("Answer id = %s" % answerJson["answer_id"])
#     print("Answer  = %s" % answerJson["answer"])
#     print("Answer conf = %s" % answerJson["answer_confidence"])
#     print("------------------")
# Out:
# Key:
# question_type
# Key:
# multiple_choice_answer
# Key:
# answers
# Key:
# image_id
# Key:
# answer_type
# Key:
# question_id

# %%
imgId_qId_answers_list = []

for answerJson in tqdm(answer_data["annotations"]):
    question_id = answerJson["question_id"]
    image_id = answerJson["image_id"]
    answer = answerJson["multiple_choice_answer"]
#     answers_arr = []
#     for indAnswerJson in answerJson["answers"]:
#         answers_arr.append(indAnswerJson["answer"])
            
    imgId_qId_answers_list.append((image_id,question_id,answer))
# Out:
# 100%|██████████| 443757/443757 [00:01<00:00, 434277.51it/s]

# %%
key2Answers_df = pd.DataFrame(imgId_qId_answers_list,columns=['image_id','question_id','answer'])

# %%
key2Answers_df
# Out:
#         image_id  question_id                    answer
# 0         458752    458752000                       net
# 1         458752    458752001                   pitcher
# 2         458752    458752002                    orange
# 3         458752    458752003                       yes
# 4         262146    262146000                     white
# 5         262146    262146001                    skiing
# 6         262146    262146002                       red
# 7         524291    524291000                   frisbee
# 8         524291    524291001                       yes
# 9         524291    524291002                   frisbee
# 10        393221    393221000                       yes
# 11        393221    393221001                       yes
# 12        393221    393221002                  contrail
# 13        393223    393223000                       yes
# 14        393223    393223001          white and purple
# 15        393223    393223002            brushing teeth
# 16        393223    393223003                       yes
# 17        393224    393224000                        no
# 18        393224    393224001                  frowning
# 19        393224    393224002                        no
# 20        393224    393224003                        no
# 21        393224    393224004                        no
# 22        393224    393224005                        no
# 23        524297    524297000                       yes
# 24        524297    524297001           black and white
# 25        524297    524297002                        no
# 26        524297    524297003                        no
# 27        393227    393227000                       yes
# 28        393227    393227001                skateboard
# 29        393227    393227002                         1
# ...          ...          ...                       ...
# 443727    305832    305832000                        no
# 443728    305832    305832001                    orange
# 443729    305832    305832002                    orange
# 443730    131058    131058000                   clothes
# 443731    131058    131058001                   blender
# 443732    131058    131058002                    purple
# 443733    131059    131059000                     green
# 443734    131059    131059001                  elephant
# 443735    131059    131059002                       yes
# 443736    131059    131059003                  elephant
# 443737    131059    131059004                  elephant
# 443738    131060    131060000                        no
# 443739    131060    131060001                teddy bear
# 443740    131060    131060002                        no
# 443741    393207    393207000                       yes
# 443742    393207    393207001                       yes
# 443743    393207    393207002                        no
# 443744    262136    262136000                       yes
# 443745    262136    262136001                150 pounds
# 443746    262136    262136002                        no
# 443747    262136    262136003          sharpening knife
# 443748    131067    131067000                      ring
# 443749    131067    131067001              fire hydrant
# 443750    131067    131067002                       yes
# 443751    524286    524286000                         2
# 443752    524286    524286001                     black
# 443753    524286    524286002                        no
# 443754    524286    524286003                     black
# 443755    524286    524286004  one is easier to type on
# 443756    524286    524286005                       yes
#
# [443757 rows x 3 columns]

# %%
key2Question_df
# Out:
#         image_id  question_id  \
# 0         458752    458752000
# 1         458752    458752001
# 2         458752    458752002
# 3         458752    458752003
# 4         262146    262146000
# 5         262146    262146001
# 6         262146    262146002
# 7         524291    524291000
# 8         524291    524291001
# 9         524291    524291002
# 10        393221    393221000
# 11        393221    393221001
# 12        393221    393221002
# 13        393223    393223000
# 14        393223    393223001
# 15        393223    393223002
# 16        393223    393223003
# 17        393224    393224000
# 18        393224    393224001
# 19        393224    393224002
# 20        393224    393224003
# 21        393224    393224004
# 22        393224    393224005
# 23        524297    524297000
# 24        524297    524297001
# 25        524297    524297002
# 26        524297    524297003
# 27        393227    393227000
# 28        393227    393227001
# 29        393227    393227002
# ...          ...          ...
# 443727    305832    305832000
# 443728    305832    305832001
# 443729    305832    305832002
# 443730    131058    131058000
# 443731    131058    131058001
# 443732    131058    131058002
# 443733    131059    131059000
# 443734    131059    131059001
# 443735    131059    131059002
# 443736    131059    131059003
# 443737    131059    131059004
# 443738    131060    131060000
# 443739    131060    131060001
# 443740    131060    131060002
# 443741    393207    393207000
# 443742    393207    393207001
# 443743    393207    393207002
# 443744    262136    262136000
# 443745    262136    262136001
# 443746    262136    262136002
# 443747    262136    262136003
# 443748    131067    131067000
# 443749    131067    131067001
# 443750    131067    131067002
# 443751    524286    524286000
# 443752    524286    524286001
# 443753    524286    524286002
# 443754    524286    524286003
# 443755    524286    524286004
# 443756    524286    524286005
#
#                                                  question
# 0               What is this photo taken looking through?
# 1                      What position is this man playing?
# 2                        What color is the players shirt?
# 3             Is this man a professional baseball player?
# 4                                 What color is the snow?
# 5                               What is the person doing?
# 6                     What color is the persons headwear?
# 7                           What is in the person's hand?
# 8                                     Is the dog waiting?
# 9         Is the dog looking at a tennis ball or frisbee?
# 10                                       Is the sky blue?
# 11                        Is there snow on the mountains?
# 12                              What is the white streak?
# 13                                    Is the window open?
# 14                          What color is the toothbrush?
# 15                               What is the child doing?
# 16                                       Is she brushing?
# 17                                    Is the man smiling?
# 18         What is the business man doing in the picture?
# 19                  Does his tie pair well with his suit?
# 20                               Does the man look happy?
# 21                                Is this photo in color?
# 22                        Is the man wearing a plain tie?
# 23      Judging from the dress, was this taken in a La...
# 24                 What colors are shown in this picture?
# 25                           Are the men on the sidewalk?
# 26                         Was this photo taken recently?
# 27                            Does the guy have a tattoo?
# 28                            What is this man riding on?
# 29       How many tattoos can be seen on this man's body?
# ...                                                   ...
# 443727                         Has the fruit been peeled?
# 443728        What kind of juice is made with this fruit?
# 443729                           What color is the fruit?
# 443730                       What are the people wearing?
# 443731                  What type of product can be seen?
# 443732                What color is the customer's shirt?
# 443733                            What color is the tree?
# 443734                   What animals are in the picture?
# 443735                        Is this animal in the wild?
# 443736                      What type of animal is shown?
# 443737                     What is the animal shown here?
# 443738              Is this a stuffed monkey in the tree?
# 443739                               What is in the tree?
# 443740                    Is the animal in the tree real?
# 443741                 Is this a black and white picture?
# 443742                              Is this photo blurry?
# 443743                                  Is this in focus?
# 443744                       Can he be sharpening blades?
# 443745                             How heavy is this man?
# 443746   Is this a normal thing to see in recent history?
# 443747                    What is man doing on his cycle?
# 443748                What links the two chains together?
# 443749                               What is this object?
# 443750                             Is this made of metal?
# 443751                      How many keyboards are there?
# 443752                        What color is the keyboard?
# 443753             Is there a computer mouse on the desk?
# 443754                        What color is the computer?
# 443755                       Why are there two keyboards?
# 443756                                  Is that a laptop?
#
# [443757 rows x 3 columns]

# %%
print(key2Question_df.shape)
print(key2Answers_df.shape)
# Out:
# (443757, 3)
# (443757, 3)

# %%
data_df = pd.merge(key2Answers_df, key2Question_df, left_on=['image_id','question_id'], right_on = ['image_id','question_id'])
data_df = data_df[["image_id","question","answer"]]
data_df = data_df.sort_values("image_id")

# %%
data_df
# Out:
#         image_id                                           question  \
# 903            9                           What is the green stuff?
# 902            9                         What color are the dishes?
# 901            9                      How many cookies can be seen?
# 95            25                       Is the giraffe in the shade?
# 94            25                     Are any of the animals eating?
# 93            25                        Are some of the trees dead?
# 92            25  What is on the ground next to the giraffe on t...
# 91            25                                 Are they at a zoo?
# 90            25                        Are both giraffes standing?
# 88            25               What is the giraffe standing behind?
# 87            25                                  Is there a zebra?
# 86            25                              Where is the giraffe?
# 85            25                            Are the animals eating?
# 84            25                    Could this photo be from a zoo?
# 83            25             What do these giraffes have in common?
# 82            25                  What is in front of the giraffes?
# 96            25              Are these giraffes living free range?
# 97            25                       How many giraffes are there?
# 89            25                    Is the giraffe eating the tree?
# 99            25                How many animals are in this photo?
# 98            25                  Is there a rock near the giraffe?
# 112           30                     Are there flowers in the vase?
# 113           30                       What is the vase sitting on?
# 114           30    Is the sun to the right or left of this flower?
# 115           30                              Are the flowers open?
# 116           30                            What color is the vase?
# 117           30                         Are all the flowers white?
# 124           34                                   Is this a horse?
# 125           34                         What is the animal eating?
# 126           34                                 How old is animal?
# ...          ...                                                ...
# 288931    581882                     Is the curtain closed or open?
# 204016    581884                                  Can you see sand?
# 204011    581884                   Are there many kites in the sky?
# 204012    581884                         Is this a desert location?
# 204013    581884           What activity is happening on the beach?
# 204014    581884                          How many kites are there?
# 204015    581884                       What can fly in the picture?
# 204045    581900  Is the rider using proper personal protective ...
# 204043    581900                   How many helmets are being worn?
# 204044    581900                      What store is in the picture?
# 204053    581903             How many purple appliances do you see?
# 204054    581903   What color is the appliance on top on the right?
# 204055    581903               What color is the largest appliance?
# 289317    581904                         Is this a crowded station?
# 289316    581904                          How many doors are there?
# 289312    581904  How long would it take you to run to the other...
# 289313    581904                                Where is the clock?
# 289315    581904                    What times does the clock have?
# 289314    581904                           Is this a train station?
# 204064    581906                               What is this object?
# 204065    581906                      Is the ground clean or dirty?
# 204066    581906                             Where is the graffiti?
# 151728    581909                     Is the boat in good condition?
# 151729    581909                   Is there any boats in the water?
# 151727    581909                         Is this boat in the water?
# 151730    581909                            Are there storm clouds?
# 204128    581921  Is this person about to fall off their snowboard?
# 204127    581921               Is there a lot of snow on the floor?
# 204129    581921             What sport is being demonstrated here?
# 204126    581921                                  Is the snow deep?
#
#                  answer
# 903            broccoli
# 902     pink and yellow
# 901                   2
# 95                   no
# 94                  yes
# 93                  yes
# 92                  log
# 91                  yes
# 90                   no
# 88                 tree
# 87                   no
# 86            near tree
# 85                  yes
# 84                  yes
# 83               eating
# 82                 tree
# 96                  yes
# 97                    2
# 89                  yes
# 99                    2
# 98                   no
# 112                 yes
# 113             railing
# 114                left
# 115                 yes
# 116               white
# 117                  no
# 124                  no
# 125               grass
# 126            10 years
# ...                 ...
# 288931           closed
# 204016              yes
# 204011              yes
# 204012              yes
# 204013      kite flying
# 204014               20
# 204015            kites
# 204045              yes
# 204043                1
# 204044       caffe nero
# 204053                1
# 204054            green
# 204055            white
# 289317              yes
# 289316                6
# 289312         1 minute
# 289313      above exits
# 289315            12:17
# 289314              yes
# 204064         suitcase
# 204065            dirty
# 204066      on sidewalk
# 151728               no
# 151729               no
# 151727               no
# 151730              yes
# 204128               no
# 204127              yes
# 204129     snowboarding
# 204126              yes
#
# [443757 rows x 3 columns]

# %% [markdown]
# # Most popular answers

# %%
NR_TOP_ANSWERS = 1000

# %%
answer_counts = data_df["answer"].value_counts()[:NR_TOP_ANSWERS]

# %%
answer_counts[:10]
# Out:
# yes      84978
# no       82516
# 1        12540
# 2        12215
# white     8916
# 3         6536
# blue      5455
# red       5201
# black     5066
# 0         4977
# Name: answer, dtype: int64

# %%
answers_arr = answer_counts.index.tolist()

# %%
answer2Index = {}
index2Answer = {}

# %%
for index in range(NR_TOP_ANSWERS):
    answer = answers_arr[index]
    answer2Index[answer] = index
    index2Answer[index] = answer

# %% [markdown]
# # Language Data Structures

# %%
def get_index_word_dicts(unique_words):
    word_index = {}
    index_word = {}
    for i,word in enumerate(unique_words):
        word_index[word] = i
        index_word[i] = word
        
    return (word_index,index_word)

def get_unique_words_helper(captions):
    unique_words = []
    words = [caption.split() for caption in captions]
   
    for word in words:
        unique_words.extend(word)
        
    unique_words = list(set(unique_words))
    
    return unique_words

def get_unique_words(data_df):
    question_counts = data_df["question"].value_counts()
    questions = [str(x)[:-1] for x in question_counts.index.tolist()]
    return get_unique_words_helper(questions)

# %%
unique_words = get_unique_words(data_df)
(word2index, index2word) = get_index_word_dicts(unique_words)

# %%
VOCAB_SIZE = len(unique_words)
VOCAB_SIZE
# Out:
# 23907

# %%
MAX_QUESTION_LENGTH  = 10

# %% [markdown]
# # Make batches

# %%
save_path = "/home/docker/fastai-courses/deeplearning1/nbs/persistent/vqa/data/"

path = save_path+"first-try/"

current_folder = train_folder
# current_folder = val_folder

base_path = path + current_folder

# %%
#Remove the last two layers to get the 4096D activations    
image_model = Vgg16().model
image_model.pop()
image_model.pop()

# %%
BATCH_SIZE = 128

# %%
nr_batches = test_data_df.shape[0] / BATCH_SIZE
nr_batches
# Out:
# 64

# %%
def get_np_vgg_features(img_id_list,base_path):
    imgId_2_img = {}
    
    images = []
    for img_id in tqdm(img_id_list):
        img = None
        if img_id in imgId_2_img:
            img = imgId_2_img[img_id]
        else:
            img = cv2.imread(base_path+"/"+"COCO_train2014_"+str(format(img_id, "012"))+".jpg")
            img = cv2.resize(img,(224,224))
            img = np.asarray(img)
            imgId_2_img[img_id] = img
        
        images.append(img)
        
    
    np_images = np.stack(images)
    np_images = np.transpose(np_images,(0,3,1,2))
    
    vgg_features = image_model.predict(np_images)
    
    return vgg_features

def write_batches(np_vgg_features, np_questions, np_answers, batch_index):
    
    save_array_with_folder_create(base_path + batch_folder + images_folder,'img_vgg_batch_'
                                  + str(format(batch_index, "06"))+ '.bc',np_vgg_features)
    
    save_array_with_folder_create(base_path + batch_folder + questions_folder,'questions_batch_'
                                  + str(format(batch_index, "06"))+ '.bc',np_questions)
    
    save_array_with_folder_create(base_path + batch_folder + answers_folder,'answers_batch_'
                                  + str(format(batch_index, "06"))+ '.bc',np_answers)

# %%
batch_folder = "batches/"
images_folder = "images/"
questions_folder = "questions/"
answers_folder = "answers/"

train_folder = "train/"

# %%
def get_indexed_qustions(raw_captions):
    indexed_captions = []
    for raw_caption in tqdm(raw_captions):
        raw_caption = raw_caption[:-1] #delete the final question mark
        indexed_caption = [word2index[caption_word] for caption_word in raw_caption.split()]
        indexed_caption = sequence.pad_sequences([indexed_caption], maxlen=MAX_QUESTION_LENGTH,padding='post')
        indexed_np_arr = np.asarray(np.squeeze(indexed_caption))

        indexed_captions.append(indexed_np_arr)
    
    return indexed_captions

# %%
# for batch_index in range(nr_batches - 1):
for batch_index in range(1):
    print("Batch = %d"%batch_index)
    current_data_df = test_data_df.iloc[batch_index*BATCH_SIZE:(batch_index+1)*BATCH_SIZE,:]
    print("current_data_df.shape = %s"%str(current_data_df.shape))
    img_id_list = current_data_df["image_id"].tolist()
    question_list = current_data_df["question"].tolist()
    answer_list = current_data_df["answer"].tolist()
    
#     np_vgg_features = get_np_vgg_features(img_id_list,train_images_path)
#     np_questions = get_indexed_qustions(question_list)
    np_answers = np.asarray(answer_list)
    
    random_answer = np_answers[1]

    print(answer2Index[random_answer])
    
#     write_batches(np_vgg_features, np_questions, np_answers,batch_index)
# Out:
# Batch = 0
# current_data_df.shape = (128, 3)
# KeyErrorTraceback (most recent call last)
# <ipython-input-472-35985aef3d66> in <module>()
#      14     random_answer = np_answers[1]
#      15
# ---> 16     print(answer2Index[random_answer])
#      17
#      18 #     write_batches(np_vgg_features, np_questions, np_answers,batch_index)
#
# KeyError: u'pink and yellow'

# %% [markdown]
# # Train Model

# %%
import re
from numpy.random import random, permutation, randn, normal
from keras.models import Sequential
from keras.layers.core import Dense, Dropout, Activation, Flatten,Lambda
from keras.layers.convolutional import Convolution2D, MaxPooling2D, ZeroPadding2D
from keras.optimizers import SGD, Adadelta, Adagrad
from keras.utils import np_utils, generic_utils
from keras.callbacks import EarlyStopping
from keras.layers.advanced_activations import PReLU, LeakyReLU
from keras.layers import Embedding,GRU,LSTM,TimeDistributed,RepeatVector,Merge
from keras.optimizers import SGD, RMSprop, Adam

# %%
EMB_SIZE = 300
vecs, words, wordidx = load_vectors("/home/docker/fastai-courses/deeplearning1/nbs/persistent/coco/glove/"+"6B."+str(EMB_SIZE)+"d")
emb = create_emb(vecs, words, wordidx,index2word,VOCAB_SIZE)
# Out:
# Found = 21907
# Not found = 1999

# %%
image_model = Sequential()
image_model.add(Dropout(0.1,input_shape=(4096,)))

# %%
language_model = Sequential()
language_model.add(Embedding(VOCAB_SIZE, 300, input_length=MAX_QUESTION_LENGTH,weights=[emb]))
language_model.add(GRU(output_dim = 512))

# %%
model = Sequential()
model.add(Merge([image_model,language_model], mode='concat', concat_axis=1))
model.add(Dense(1024, activation = "relu"))
model.add(Dropout(0.5))
model.add(Dense(1024, activation = "relu"))
model.add(Dropout(0.5))
model.add(Dense(NR_TOP_ANSWERS))
model.add(Activation('softmax'))

model.compile(loss='categorical_crossentropy', optimizer='adam')

# %%
model.summary()
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# dropout_17 (Dropout)             (None, 4096)          0
# ____________________________________________________________________________________________________
# embedding_5 (Embedding)          (None, 10, 300)       7172100
# ____________________________________________________________________________________________________
# gru_3 (GRU)                      (None, 512)           1248768
# ____________________________________________________________________________________________________
# dense_22 (Dense)                 (None, 1024)          4719616     merge_6[0][0]
# ____________________________________________________________________________________________________
# dropout_18 (Dropout)             (None, 1024)          0           dense_22[0][0]
# ____________________________________________________________________________________________________
# dense_23 (Dense)                 (None, 1024)          1049600     dropout_18[0][0]
# ____________________________________________________________________________________________________
# dropout_19 (Dropout)             (None, 1024)          0           dense_23[0][0]
# ____________________________________________________________________________________________________
# dense_24 (Dense)                 (None, 1000)          1025000     dropout_19[0][0]
# ____________________________________________________________________________________________________
# activation_5 (Activation)        (None, 1000)          0           dense_24[0][0]
# ====================================================================================================
# Total params: 15,215,084
# Trainable params: 15,215,084
# Non-trainable params: 0
# ____________________________________________________________________________________________________

# %%
def generate_from_path():
    
    images_dir = base_path + batch_folder + images_folder    
    questions_dir = base_path + batch_folder + questions_folder
    answers_dir = base_path + batch_folder + answers_folder

    images_paths = os.listdir(images_dir)
    questions_paths = os.listdir(questions_dir)
    answers_paths = os.listdir(answers_dir)
    
    images_paths.sort()
    questions_paths.sort()
    answers_paths.sort()
    
    nr_batches = len(images_paths)
    
    while(1):
    
        for batch_index in range(nr_batches):
            images_batch = load_array(images_dir + images_paths[batch_index])
            questions_batch = load_array(questions_dir + questions_paths[batch_index])
            answers_batch = load_array(answers_dir + answers_paths[batch_index])
        
            yield([images_batch,questions_batch],answers_batch)

# %%
model.fit_generator(generate_from_path(),
                    samples_per_epoch = 2048,
                    nb_epoch = 10)
# Out:
# Epoch 1/10
# ValueErrorTraceback (most recent call last)
# <ipython-input-462-93a1f67e0657> in <module>()
#       1 model.fit_generator(generate_from_path(),
#       2                     samples_per_epoch = 2048,
# ----> 3                     nb_epoch = 10)
#
# /opt/conda/lib/python2.7/site-packages/keras/models.pyc in fit_generator(self, generator, samples_per_epoch, nb_epoch, verbose, callbacks, validation_data, nb_val_samples, class_weight, max_q_size, nb_worker, pickle_safe, initial_epoch, **kwargs)
#     933                                         nb_worker=nb_worker,
#     934                                         pickle_safe=pickle_safe,
# --> 935                                         initial_epoch=initial_epoch)
#     936
#     937     def evaluate_generator(self, generator, val_samples,
#
# /opt/conda/lib/python2.7/site-packages/keras/engine/training.pyc in fit_generator(self, generator, samples_per_epoch, nb_epoch, verbose, callbacks, validation_data, nb_val_samples, class_weight, max_q_size, nb_worker, pickle_safe, initial_epoch)
#    1555                     outs = self.train_on_batch(x, y,
#    1556                                                sample_weight=sample_weight,
# -> 1557                                                class_weight=class_weight)
#    1558
#    1559                     if not isinstance(outs, list):
#
# /opt/conda/lib/python2.7/site-packages/keras/engine/training.pyc in train_on_batch(self, x, y, sample_weight, class_weight)
#    1312             sample_weight=sample_weight,
#    1313             class_weight=class_weight,
# -> 1314             check_batch_axis=True)
#    1315         if self.uses_learning_phase and not isinstance(K.learning_phase, int):
#    1316             ins = x + y + sample_weights + [1.]
#
# /opt/conda/lib/python2.7/site-packages/keras/engine/training.pyc in _standardize_user_data(self, x, y, sample_weight, class_weight, check_batch_axis, batch_size)
#    1031                                    output_shapes,
#    1032                                    check_batch_axis=False,
# -> 1033                                    exception_prefix='model target')
#    1034         sample_weights = standardize_sample_weights(sample_weight,
#    1035                                                     self.output_names)
#
# /opt/conda/lib/python2.7/site-packages/keras/engine/training.pyc in standardize_input_data(data, names, shapes, check_batch_axis, exception_prefix)
#     122                             ' to have shape ' + str(shapes[i]) +
#     123                             ' but got array with shape ' +
# --> 124                             str(array.shape))
#     125     return arrays
#     126
#
# ValueError: Error when checking model target: expected activation_5 to have shape (None, 1000) but got array with shape (128, 1)
