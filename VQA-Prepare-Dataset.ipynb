# %%
import json
import pandas as pd
from tqdm import tqdm
from vgg16 import Vgg16
import numpy as np
import PIL.Image
from utils import *
from matplotlib import pyplot as plt
import cv2
import os
import cPickle as pickle
from keras.preprocessing import sequence

import shutil
import string

import collections
import nltk
from nltk.stem.wordnet import WordNetLemmatizer
from nltk.corpus import stopwords

import re
from numpy.random import random, permutation, randn, normal
from keras.models import Sequential
from keras.layers.core import Dense, Dropout, Activation, Flatten,Lambda
from keras.layers.convolutional import Convolution2D, MaxPooling2D, ZeroPadding2D
from keras.optimizers import SGD, Adadelta, Adagrad
from keras.utils import np_utils, generic_utils
from keras.callbacks import EarlyStopping
from keras.layers.advanced_activations import PReLU, LeakyReLU
from keras.layers import Embedding,GRU,LSTM,TimeDistributed,RepeatVector,Merge
from keras.optimizers import SGD, RMSprop, Adam

import preprocessor as preproc
# Out:
# Using Theano backend.
# Using gpu device 0: GeForce GTX 1080 (CNMeM is disabled, cuDNN 5110)
# /opt/conda/lib/python2.7/site-packages/theano/sandbox/cuda/__init__.py:600: UserWarning: Your cuDNN version is more recent than the one Theano officially supports. If you see any problems, try updating Theano or downgrading cuDNN to version 5.
#   warnings.warn(warn)

# %%
def save_array_with_folder_create(folder_path,arr_name,arr):
    if not os.path.exists(folder_path):
        print("Creating folder: "+folder_path)
        os.makedirs(folder_path)
        
    save_array(folder_path + arr_name, arr)
    
def load_vectors(loc):
    return (load_array(loc+'.dat'),
        pickle.load(open(loc+'_words.pkl','rb')),
        pickle.load(open(loc+'_idx.pkl','rb')))   




def create_emb(vecs,words,wordidx,index2word,vocab_size):
    n_fact = vecs.shape[1]
    emb = np.zeros((vocab_size, n_fact))

    found = 0
    not_found = 0
    
    exclude = set(string.punctuation)
    for i in range(1,len(emb)):
        word = index2word[i]
        word = ''.join(ch for ch in word if ch not in exclude).lower()
        if word and re.match(r"^[a-zA-Z0-9\-]*$", word) and word in wordidx:
            src_idx = wordidx[word]
            emb[i] = vecs[src_idx]
            found +=1
        else:
            # If we can't find the word in glove, randomly initialize
            emb[i] = normal(scale=0.6, size=(n_fact,))
            not_found+=1
#             print(word)

    # This is our "rare word" id - we want to randomly initialize
    emb[-1] = normal(scale=0.6, size=(n_fact,))
    emb/=3
    
    print("Found = %d"%found)
    print("Not found = %d"%not_found)
        
    return emb

# %% [markdown]
# ## Pairing

# %%
# current_folder = train_folder
current_folder = val_folder

save_path = "/home/docker/fastai-courses/deeplearning1/nbs/persistent/vqa/data/"
path = save_path+"first-try/"
base_path = path + current_folder

# %%
pairing_path = "../../vqa/raw_questions/"+current_folder+"pairing.json"
with open(pairing_path) as data_file:    
        data = json.load(data_file)
     
    
imgId_qId_question_list = []
for questionJson in tqdm(data["questions"]):
    imgId_qId_question_list.append((questionJson["image_id"],questionJson["question_id"],questionJson["question"]))
# Out:
# 100%|██████████| 214354/214354 [00:00<00:00, 791324.62it/s]

# %%
key2Question_df = pd.DataFrame(imgId_qId_question_list,columns=['image_id', 'question_id', 'question'])
key2Question_df
# Out:
#         image_id  question_id  \
# 0         262148    262148000
# 1         262148    262148001
# 2         262148    262148002
# 3         393225    393225000
# 4         393225    393225001
# 5         393225    393225002
# 6         393225    393225003
# 7         393226    393226000
# 8         393226    393226001
# 9         393226    393226002
# 10        240301    240301000
# 11        240301    240301001
# 12        240301    240301002
# 13        131089    131089000
# 14        131089    131089001
# 15        131089    131089002
# 16        131089    131089003
# 17        131089    131089004
# 18        262162    262162000
# 19        262162    262162001
# 20        262162    262162002
# 21        262162    262162003
# 22        262162    262162004
# 23        262162    262162005
# 24        262162    262162006
# 25        262162    262162007
# 26        262162    262162008
# 27        262162    262162009
# 28        262162    262162010
# 29        262162    262162011
# ...          ...          ...
# 214324    262113    262113004
# 214325    524263    524263000
# 214326    524263    524263001
# 214327    524263    524263002
# 214328    524263    524263003
# 214329    393203    393203000
# 214330    393203    393203001
# 214331    393203    393203002
# 214332    393203    393203003
# 214333    131063    131063000
# 214334    131063    131063001
# 214335    131063    131063002
# 214336    131063    131063003
# 214337    131063    131063004
# 214338    131063    131063005
# 214339    524280    524280000
# 214340    524280    524280001
# 214341    524280    524280002
# 214342    524282    524282000
# 214343    524282    524282001
# 214344    524282    524282002
# 214345    524282    524282003
# 214346    524282    524282004
# 214347    524282    524282005
# 214348    524282    524282006
# 214349    393212    393212000
# 214350    393212    393212001
# 214351    393212    393212002
# 214352    393212    393212003
# 214353    393212    393212004
#
#                                                  question
# 0                                    Where is he looking?
# 1            What are the people in the background doing?
# 2                                   What is he on top of?
# 3                   What website copyrighted the picture?
# 4                                  Is this a creamy soup?
# 5                               Is this rice noodle soup?
# 6                       What is to the right of the soup?
# 7                    What is the man doing in the street?
# 8                           How many photo's can you see?
# 9                   What does the truck on the left sell?
# 10          Why is there a gap between the roof and wall?
# 11                        Is it daylight in this picture?
# 12                            Why is the cow laying down?
# 13               What color is the grass in this picture?
# 14                           Did the batter hit the ball?
# 15                             How many are playing ball?
# 16              Is there a chain link fence in the image?
# 17                           Is the boy playing baseball?
# 18                               Is that a folding chair?
# 19                                         How many beds?
# 20                           What color is the bedspread?
# 21                           How many pictures are there?
# 22                             Are these twin mattresses?
# 23                   How many sources of light are there?
# 24                  Is this room decorated for the 1970s?
# 25                        Are the lights on in this room?
# 26                                   Are the windows big?
# 27                             What is the chair made of?
# 28                        Is this room in someone's home?
# 29                                    Which room is this?
# ...                                                   ...
# 214324                           Are these navel oranges?
# 214325           What time of day was this picture taken?
# 214326   Why do the bears have chains around their necks?
# 214327                        How many animals are there?
# 214328                      Where is the stump of a tree?
# 214329              Where are the animals in the picture?
# 214330     What kind of animals are grazing in the grass?
# 214331                     How many rocks can be counted?
# 214332  Why can there be no blue sky seen in this pict...
# 214333                                 What room is this?
# 214334                          How many tiles are there?
# 214335           Was this photo taken at someone's house?
# 214336                            Who uses this bathroom?
# 214337     What is the name of this his and her bathroom?
# 214338                 Is this bathroom clean or clutter?
# 214339                   Is the cat's whole body visible?
# 214340                        What color is the eyes cat?
# 214341                                     How many cats?
# 214342                           What color is the court?
# 214343                        How many players are there?
# 214344                             Are the players tired?
# 214345                What is stretched across the court?
# 214346                                 What game is this?
# 214347                       What color is the barricade?
# 214348                    Are these women wearing skirts?
# 214349               What is the main color in the photo?
# 214350                  What is the meaning of this sign?
# 214351                               What is on the sign?
# 214352                Does the arrow point left or right?
# 214353                           Is the sign for traffic?
#
# [214354 rows x 3 columns]

# %% [markdown]
# # Answers

# %%
answers_path = "../../vqa/raw_questions/"+current_folder+"answers.json"
with open(answers_path) as data_file:    
        answer_data = json.load(data_file)
        
imgId_qId_answers_list = []

for answerJson in tqdm(answer_data["annotations"]):
    question_id = answerJson["question_id"]
    image_id = answerJson["image_id"]
    answer = answerJson["multiple_choice_answer"]
    imgId_qId_answers_list.append((image_id,question_id,answer))
# Out:
# 100%|██████████| 214354/214354 [00:00<00:00, 358001.30it/s]

# %%
key2Answers_df = pd.DataFrame(imgId_qId_answers_list,columns=['image_id','question_id','answer'])

# %%
key2Answers_df
# Out:
#         image_id  question_id                 answer
# 0         262148    262148000                   down
# 1         262148    262148001               watching
# 2         262148    262148002           picnic table
# 3         393225    393225000         foodiebakercom
# 4         393225    393225001                     no
# 5         393225    393225002                    yes
# 6         393225    393225003             chopsticks
# 7         393226    393226000                walking
# 8         393226    393226001                      1
# 9         393226    393226002              ice cream
# 10        240301    240301000                    yes
# 11        240301    240301001                    yes
# 12        240301    240301002                  tired
# 13        131089    131089000                  green
# 14        131089    131089001                    yes
# 15        131089    131089002                      1
# 16        131089    131089003                     no
# 17        131089    131089004                    yes
# 18        262162    262162000                     no
# 19        262162    262162001                      1
# 20        262162    262162002                  white
# 21        262162    262162003                      7
# 22        262162    262162004                     no
# 23        262162    262162005                      1
# 24        262162    262162006                     no
# 25        262162    262162007                     no
# 26        262162    262162008                    yes
# 27        262162    262162009                leather
# 28        262162    262162010                    yes
# 29        262162    262162011                bedroom
# ...          ...          ...                    ...
# 214324    262113    262113004                    yes
# 214325    524263    524263000                morning
# 214326    524263    524263001  to keep from escaping
# 214327    524263    524263002                      2
# 214328    524263    524263003                 middle
# 214329    393203    393203000                  sheep
# 214330    393203    393203001                  sheep
# 214331    393203    393203002                      7
# 214332    393203    393203003             too cloudy
# 214333    131063    131063000               bathroom
# 214334    131063    131063001                   many
# 214335    131063    131063002                    yes
# 214336    131063    131063003                 people
# 214337    131063    131063004               bathroom
# 214338    131063    131063005                clutter
# 214339    524280    524280000                     no
# 214340    524280    524280001                  green
# 214341    524280    524280002                      1
# 214342    524282    524282000                    red
# 214343    524282    524282001                      2
# 214344    524282    524282002                     no
# 214345    524282    524282003                  lines
# 214346    524282    524282004                 tennis
# 214347    524282    524282005                   gray
# 214348    524282    524282006                    yes
# 214349    393212    393212000                  green
# 214350    393212    393212001                go left
# 214351    393212    393212002                  arrow
# 214352    393212    393212003                   left
# 214353    393212    393212004                    yes
#
# [214354 rows x 3 columns]

# %%
key2Question_df
# Out:
#         image_id  question_id  \
# 0         262148    262148000
# 1         262148    262148001
# 2         262148    262148002
# 3         393225    393225000
# 4         393225    393225001
# 5         393225    393225002
# 6         393225    393225003
# 7         393226    393226000
# 8         393226    393226001
# 9         393226    393226002
# 10        240301    240301000
# 11        240301    240301001
# 12        240301    240301002
# 13        131089    131089000
# 14        131089    131089001
# 15        131089    131089002
# 16        131089    131089003
# 17        131089    131089004
# 18        262162    262162000
# 19        262162    262162001
# 20        262162    262162002
# 21        262162    262162003
# 22        262162    262162004
# 23        262162    262162005
# 24        262162    262162006
# 25        262162    262162007
# 26        262162    262162008
# 27        262162    262162009
# 28        262162    262162010
# 29        262162    262162011
# ...          ...          ...
# 214324    262113    262113004
# 214325    524263    524263000
# 214326    524263    524263001
# 214327    524263    524263002
# 214328    524263    524263003
# 214329    393203    393203000
# 214330    393203    393203001
# 214331    393203    393203002
# 214332    393203    393203003
# 214333    131063    131063000
# 214334    131063    131063001
# 214335    131063    131063002
# 214336    131063    131063003
# 214337    131063    131063004
# 214338    131063    131063005
# 214339    524280    524280000
# 214340    524280    524280001
# 214341    524280    524280002
# 214342    524282    524282000
# 214343    524282    524282001
# 214344    524282    524282002
# 214345    524282    524282003
# 214346    524282    524282004
# 214347    524282    524282005
# 214348    524282    524282006
# 214349    393212    393212000
# 214350    393212    393212001
# 214351    393212    393212002
# 214352    393212    393212003
# 214353    393212    393212004
#
#                                                  question
# 0                                    Where is he looking?
# 1            What are the people in the background doing?
# 2                                   What is he on top of?
# 3                   What website copyrighted the picture?
# 4                                  Is this a creamy soup?
# 5                               Is this rice noodle soup?
# 6                       What is to the right of the soup?
# 7                    What is the man doing in the street?
# 8                           How many photo's can you see?
# 9                   What does the truck on the left sell?
# 10          Why is there a gap between the roof and wall?
# 11                        Is it daylight in this picture?
# 12                            Why is the cow laying down?
# 13               What color is the grass in this picture?
# 14                           Did the batter hit the ball?
# 15                             How many are playing ball?
# 16              Is there a chain link fence in the image?
# 17                           Is the boy playing baseball?
# 18                               Is that a folding chair?
# 19                                         How many beds?
# 20                           What color is the bedspread?
# 21                           How many pictures are there?
# 22                             Are these twin mattresses?
# 23                   How many sources of light are there?
# 24                  Is this room decorated for the 1970s?
# 25                        Are the lights on in this room?
# 26                                   Are the windows big?
# 27                             What is the chair made of?
# 28                        Is this room in someone's home?
# 29                                    Which room is this?
# ...                                                   ...
# 214324                           Are these navel oranges?
# 214325           What time of day was this picture taken?
# 214326   Why do the bears have chains around their necks?
# 214327                        How many animals are there?
# 214328                      Where is the stump of a tree?
# 214329              Where are the animals in the picture?
# 214330     What kind of animals are grazing in the grass?
# 214331                     How many rocks can be counted?
# 214332  Why can there be no blue sky seen in this pict...
# 214333                                 What room is this?
# 214334                          How many tiles are there?
# 214335           Was this photo taken at someone's house?
# 214336                            Who uses this bathroom?
# 214337     What is the name of this his and her bathroom?
# 214338                 Is this bathroom clean or clutter?
# 214339                   Is the cat's whole body visible?
# 214340                        What color is the eyes cat?
# 214341                                     How many cats?
# 214342                           What color is the court?
# 214343                        How many players are there?
# 214344                             Are the players tired?
# 214345                What is stretched across the court?
# 214346                                 What game is this?
# 214347                       What color is the barricade?
# 214348                    Are these women wearing skirts?
# 214349               What is the main color in the photo?
# 214350                  What is the meaning of this sign?
# 214351                               What is on the sign?
# 214352                Does the arrow point left or right?
# 214353                           Is the sign for traffic?
#
# [214354 rows x 3 columns]

# %%
print(key2Question_df.shape)
print(key2Answers_df.shape)
# Out:
# (214354, 3)
# (214354, 3)

# %%
all_data_df = pd.merge(key2Answers_df, key2Question_df, 
                       left_on=['image_id','question_id'], 
                       right_on = ['image_id','question_id'])

all_data_df = all_data_df[["image_id","question","answer"]]
all_data_df = all_data_df.sort_values("image_id")

# %%
all_data_df
# Out:
#         image_id                                         question      answer
# 62            42                    What color are the gym shoes?       white
# 64            42                     What color is the flip flop?         red
# 63            42                      Is there a red sandal here?         yes
# 915           73                      What is the license number?     sv-6260
# 916           73                    Is this a motorcycle or bike?  motorcycle
# 917           73                          What color is the bike?       black
# 918           73        What letter and 3 numbers are on the tag?     sv-6260
# 160           74                     Does this dog have a collar?          no
# 161           74                         Where is the dog laying?    sidewalk
# 162           74                           What is the dog doing?    sleeping
# 253          133                            Is this a child room?         yes
# 252          133                              What color is lamp?        blue
# 254          133  What size mattress would you need for this bed?        twin
# 263          136                             Is this in a museum?          no
# 264          136             How many animals are in the picture?           2
# 265          136                    What kind of animal is shown?     giraffe
# 266          139             What is the woman in the room doing?     talking
# 267          139                           How many yellow vases?           1
# 268          139                         What color is the floor?       brown
# 269          139                        What color is the flower?        pink
# 274          143       What color is the tip of the birds' tails?      yellow
# 276          143                        Who many birds are black?           0
# 275          143                  How many birds are in the tree?           8
# 334          164                      How many paper towel rolls?           1
# 337          164                          What color is the wall?       white
# 335          164           What is the color of the refrigerator?       white
# 336          164                                 Is the light on?          no
# 359          192                      What sport is being played?    baseball
# 360          192              Is the catcher wearing safety gear?         yes
# 361          192                   What is the name of the teams?        cubs
# ...          ...                                              ...         ...
# 103167    581863                       What kind of room is this?    bathroom
# 103222    581886             Which surfer's board is upside down?        left
# 103223    581886                            What is on the beach?     surfers
# 103224    581886                         Is the man old or young?       young
# 103225    581886                      What is the man sitting on?        sand
# 103226    581886                     How many surfers do you see?           2
# 103227    581887            What is the number on the green sign?          10
# 103228    581887                      How many signs can be seen?           3
# 103229    581887                              Is this a driveway?          no
# 103230    581887                                    Is it cloudy?         yes
# 103235    581899                 What is the square on the right?      window
# 103237    581899                      Are these passenger trains?         yes
# 103236    581899                     What color are these trains?        blue
# 103274    581913                      How many pastries are here?           4
# 103273    581913              How many calories are these donuts?         300
# 103271    581913                  How many pink donuts are shown?           0
# 103272    581913                      How round are these donuts?       round
# 103280    581913             Which doughnut will get eaten first?   chocolate
# 103279    581913                    What color are the sprinkles?     rainbow
# 103278    581913                 Do any donuts contain sprinkles?         yes
# 103277    581913    What covers the top of the top left doughnut?   sprinkles
# 103276    581913           How many doughnuts are in the picture?           4
# 103275    581913             What kind of donut is in the basket?   chocolate
# 103270    581913                Are all of these donuts the same?          no
# 103290    581929            What is the horse doing in the field?      eating
# 103292    581929                         What color is the grass?       green
# 103293    581929              Are the horses facing the same way?          no
# 103294    581929   What is the copyright year shown in the photo?        2012
# 103295    581929                      What colors are the animal?       brown
# 103291    581929                   What is the front horse doing?     grazing
#
# [214354 rows x 3 columns]

# %% [markdown]
# # Select only most popular answers

# %%
NR_TOP_ANSWERS = 1000

# %% [markdown]
# ## For Train

# %%
answer_counts = all_data_df["answer"].value_counts()[:NR_TOP_ANSWERS]
answers_arr = answer_counts.index.tolist()

answer2Index = {}
index2Answer = {}

for index in range(NR_TOP_ANSWERS):
    answer = answers_arr[index]
    answer2Index[answer] = index
    index2Answer[index] = answer
    
if not os.path.exists(path+general_datastruct_folder):
    os.makedirs(path+general_datastruct_folder)

preproc.save_obj(answers_arr,path+general_datastruct_folder+"answers_arr")
preproc.save_obj(answer2Index,path+general_datastruct_folder+"answer2Index")
preproc.save_obj(index2Answer,path+general_datastruct_folder+"index2Answer")

# %% [markdown]
# ## For Valid

# %%
answers_arr = preproc.load_obj(path+general_datastruct_folder+"answers_arr")
answer2Index = preproc.load_obj(path+general_datastruct_folder+"answer2Index")
index2Answer = preproc.load_obj(path+general_datastruct_folder+"index2Answer")

# %% [markdown]
# ## Filtering

# %%
popular_answers_df = pd.DataFrame(answers_arr,columns = ["answer"])
popular_answers_df
# Out:
#              answer
# 0               yes
# 1                no
# 2                 1
# 3                 2
# 4             white
# 5                 3
# 6              blue
# 7               red
# 8             black
# 9                 0
# 10                4
# 11            brown
# 12            green
# 13           yellow
# 14                5
# 15             gray
# 16          nothing
# 17            right
# 18          frisbee
# 19         baseball
# 20             left
# 21             none
# 22           tennis
# 23                6
# 24             wood
# 25           orange
# 26         bathroom
# 27            pizza
# 28             pink
# 29          kitchen
# ..              ...
# 970          cherry
# 971           tired
# 972            mutt
# 973  white and gray
# 974           cones
# 975        in front
# 976            thin
# 977             oil
# 978         regular
# 979        children
# 980             fur
# 981      foreground
# 982          garage
# 983            foil
# 984           chips
# 985          tattoo
# 986              34
# 987         plaster
# 988          corner
# 989     hello kitty
# 990          dugout
# 991    one on right
# 992            army
# 993        on grass
# 994            main
# 995          boxing
# 996            taxi
# 997         harness
# 998         t-shirt
# 999         drywall
#
# [1000 rows x 1 columns]

# %%
data_df = pd.merge(all_data_df, popular_answers_df,  
                                     how='inner', 
                                     left_on=['answer'], right_on = ['answer'])
data_df = data_df.sort_values("image_id")
data_df
# Out:
#         image_id                                         question      answer
# 0             42                    What color are the gym shoes?       white
# 6794          42                      Is there a red sandal here?         yes
# 4311          42                     What color is the flip flop?         red
# 47774         73                          What color is the bike?       black
# 47522         73                    Is this a motorcycle or bike?  motorcycle
# 50286         74                     Does this dog have a collar?          no
# 90481         74                           What is the dog doing?    sleeping
# 90368         74                         Where is the dog laying?    sidewalk
# 6795         133                            Is this a child room?         yes
# 93309        133  What size mattress would you need for this bed?        twin
# 90576        133                              What color is lamp?        blue
# 50287        136                             Is this in a museum?          no
# 99077        136                    What kind of animal is shown?     giraffe
# 93332        136             How many animals are in the picture?           2
# 107448       139                        What color is the flower?        pink
# 99428        139                           How many yellow vases?           1
# 99377        139             What is the woman in the room doing?     talking
# 105521       139                         What color is the floor?       brown
# 111677       143                  How many birds are in the tree?           8
# 109331       143                        Who many birds are black?           0
# 107980       143       What color is the tip of the birds' tails?      yellow
# 99429        164                      How many paper towel rolls?           1
# 2            164           What is the color of the refrigerator?       white
# 50288        164                                 Is the light on?          no
# 1            164                          What color is the wall?       white
# 6796         192              Is the catcher wearing safety gear?         yes
# 112153       192                      What sport is being played?    baseball
# 113115       196                         What is the yellow food?        corn
# 6797         196                     Is this going to be a feast?         yes
# 6798         196  Are there lots of healthy options on the table?         yes
# ...          ...                                              ...         ...
# 93307     581831                       What color are the shirts?        blue
# 128406    581863                       What kind of room is this?    bathroom
# 107446    581863                          What color is the door?       brown
# 90364     581863                       Is there a shower curtain?          no
# 179145    581886                         Is the man old or young?       young
# 170122    581886                      What is the man sitting on?        sand
# 99076     581886                     How many surfers do you see?           2
# 133413    581886             Which surfer's board is upside down?        left
# 134258    581887            What is the number on the green sign?          10
# 90365     581887                              Is this a driveway?          no
# 119292    581887                      How many signs can be seen?           3
# 47519     581887                                    Is it cloudy?         yes
# 159506    581899                 What is the square on the right?      window
# 47520     581899                      Are these passenger trains?         yes
# 93308     581899                     What color are these trains?        blue
# 111676    581913                  How many pink donuts are shown?           0
# 162542    581913                    What color are the sprinkles?     rainbow
# 164130    581913    What covers the top of the top left doughnut?   sprinkles
# 153505    581913                      How round are these donuts?       round
# 153395    581913             What kind of donut is in the basket?   chocolate
# 153394    581913             Which doughnut will get eaten first?   chocolate
# 90366     581913                Are all of these donuts the same?          no
# 47521     581913                 Do any donuts contain sprinkles?         yes
# 130411    581913                      How many pastries are here?           4
# 130412    581913           How many doughnuts are in the picture?           4
# 107447    581929                      What colors are the animal?       brown
# 165587    581929            What is the horse doing in the field?      eating
# 156700    581929                   What is the front horse doing?     grazing
# 90367     581929              Are the horses facing the same way?          no
# 126811    581929                         What color is the grass?       green
#
# [186503 rows x 3 columns]

# %%
print(all_data_df.shape)
print(data_df.shape)
# Out:
# (214354, 3)
# (186503, 3)

# %%
data_df = data_df[:8192]
print(data_df.shape)
# Out:
# (8192, 3)

# %%
if not os.path.exists(base_path):
    os.makedirs(base_path)
    
data_df.to_csv(base_path+"data_df.csv")

# %% [markdown]
# # Language Data Structures => After train & val

# %%
def get_index_word_dicts(unique_words):
    word_index = {}
    index_word = {}
    for i,word in enumerate(unique_words):
        word_index[word] = i
        index_word[i] = word
        
    return (word_index,index_word)

def get_unique_words_helper(captions):
    unique_words = []
    words = [caption.split() for caption in captions]
   
    for word in words:
        unique_words.extend(word)
        
    unique_words = list(set(unique_words))
    
    return unique_words

def get_unique_words(data_df):
    question_counts = data_df["question"].value_counts()
    questions = [str(x)[:-1] for x in question_counts.index.tolist()]
    return get_unique_words_helper(questions)

# %%
train_df = pd.read_csv(path+train_folder+"data_df.csv")
val_df = pd.read_csv(path+val_folder+"data_df.csv")

# %%
print(train_df.shape)
print(val_df.shape)
# Out:
# (8192, 4)
# (8192, 4)

# %%
joined_df = pd.concat([train_df,val_df])
joined_df.shape
# Out:
# (16384, 4)

# %%
unique_words = get_unique_words(joined_df)
(word2index, index2word) = get_index_word_dicts(unique_words)

# %%
VOCAB_SIZE = len(unique_words)
VOCAB_SIZE
# Out:
# 4469

# %%
general_datastruct_folder = "general-data-structures/"

# %%
if not os.path.exists(path+general_datastruct_folder):
    os.makedirs(path+general_datastruct_folder)

preproc.save_obj(unique_words,path+general_datastruct_folder+"unique_words")
preproc.save_obj(word2index,path+general_datastruct_folder+"word2index")
preproc.save_obj(index2word,path+general_datastruct_folder+"index2word")
